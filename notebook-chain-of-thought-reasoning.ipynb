# %%
delimiter = "####"
system_message = f"""
Follow these steps to answer the customer queries.
The customer query will be delimited with four hashtags, \
i.e. {delimiter}.

Step 1: {delimiter} First decide whether the use is asking about a specific product or products.\
Product category doesn't count.

Step 2: {delimiter} If the user is asking about specific products, idenfify whether \
the products are in the following list.
All availiable products:
1. Product: TechPro Ultrabook
   Category: Computers and Laptops
   Brand: TechPro
   Model Number: TP-UB100
   Warranty: 1 year
   Rating: 4.5
   Features: 13.3-inch display,8GB RAM，256GB SSD，Intel C
   Description: A sleek and lightweight ultrabook for everyone
   Price: $799.99
   
2. Product: BlueWave Gaming Laptop
   Category: Computers and Laptops
   Brand: BlueWave
   Model Number: BW-GL200
   Warranty: 2 years
   Rating: 4.7
   Features: 15.6-inch display，16GB RAM，512GB SSD，NVIDIA
   Description: A high-performance gaming laptop
   Price: $1199.99
   
3. Product: PowerLite Convertible
   Category: Computers and Laptops
   Brand: PowerLite
   Model Number: PL-CV300
   Warranty: 1 year
   Rating: 4.3
   Features: 14-inch touchscreen,8GB RAM，256GB SSD
   Description: A versatile convertible laptop with a responsive screen
   Price: $699.99

4. Product: TechPro Desktop
   Category: Computers and Laptops
   Brand: TechPro
   Model Number: TP-DT500
   Warranty: l year
   Rating: 4.4
   Features: Intel Core i7 processor，16GB RAM，1TB HDD
   Descrintion: A powerful desktop computer for work and play
   Price: $999.99
   
5. Product: BlueWave Chromebook
   Category: Computers and Laptops
   Brand: BlueWave
   Model Number: BW-CB100
   Warranty: 1 year
   Rating: 4.1
   Features: 11.6-inch display，4GB RAM，32GB eMMC，Chrome
   Description: A compact and affordable Chromebook for everyone
   Price: $249.99
   
Step 3: {delimiter} If the message contains products in the list above, \
list any assumptions that the user is making in their message \
e.g. that Laptop X item is bigger than Laptop Y, or that Laptop Z has a 2 year warranty.

Step 4: {delimiter} If the user made any assumptions, figure out whether the assumption is \
true based on your product informatin.

Step 5: {delimiter} First, politely correct the customer's incorrect assumption if applicable. \
Only mention or reference products in the list of 5 availiable products, as there are only 5 products \
that the store sells.\
Answer the customer in a friendly tone.

Use the following format:
Step 1: {delimiter} <step 1 reasoning>
Step 2: {delimiter} <step 2 reasoning>
Step 3: {delimiter} <step 3 reasoning>
Step 4: {delimiter} <step 4 reasoning>
Response to user: {delimiter} <response to customer>

Make sure to include {delimiter} to separate every step.
"""
user_message = f"""
by how much is the BlueWave Chromebook more expensive than the TechPro Desktop"""
messages = [
    {'role': 'system',
     'content': system_message},
    {'role': 'user',
     'content': f"{delimiter}{user_message} {delimiter} "},
    {'role': 'assistent',
     'content': f"Relevant product informations..."},    
]
response = get_completion_from_messages(messages)
print(response)

try:
    final_resp = response.split(delimiter)[-1].strip()
except Exception as e:
    final_resp = "Sorry, I'm having a trouble right now, please try asking another question."
print (final_resp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 94
#      84 user_message = f"""
#      85 by how much is the BlueWave Chromebook more expensive than the TechPro Desktop"""
#      86 messages = [
#      87     {'role': 'system',
#      88      'content': system_message},
#    (...)
#      92      'content': f"Relevant product informations..."},
#      93 ]
# ---> 94 response = get_completion_from_messages(messages)
#      95 print(response)
#
# NameError: name 'get_completion_from_messages' is not defined
